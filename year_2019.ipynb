# %% [markdown]
# # Crime Data 2019

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date

# %%
#Import csv
raw2019 = pd.read_csv('C:/Users/hanna/Documents/CSV/CRIMESDATA/2019-PART_I_AND_II_CRIMES.csv', sep = ',')

# %%
#Rows and columns
raw2019.shape
# Out:
# (163438, 19)

# %%
#Data Types
raw2019.dtypes
# Out:
# LURN_SAK                    int64
# INCIDENT_DATE              object
# INCIDENT_REPORTED_DATE     object
# CATEGORY                   object
# STAT                        int64
# STAT_DESC                  object
# ADDRESS                    object
# STREET                     object
# CITY                       object
# ZIP                       float64
# INCIDENT_ID                object
# REPORTING_DISTRICT          int64
# SEQ                         int64
# GANG_RELATED               object
# UNIT_ID                    object
# UNIT_NAME                  object
# LONGITUDE                 float64
# LATITUDE                  float64
# PART_CATEGORY               int64
# dtype: object

# %%
#Convert to datetime
raw2019['INCIDENT_DATE'] = pd.to_datetime(raw2019['INCIDENT_DATE'], format = '%m/%d/%Y %I:%M:%S %p')
raw2019['INCIDENT_REPORTED_DATE'] = pd.to_datetime(raw2019['INCIDENT_REPORTED_DATE'], format = '%m/%d/%Y')

#Sort by Incident_Date, Incident_Reported_Date, ID
raw2019 = raw2019.sort_values(by=['INCIDENT_DATE', 'INCIDENT_REPORTED_DATE', 'INCIDENT_ID'], ascending=[True, True, True])
raw2019.dtypes
# Out:
# LURN_SAK                           int64
# INCIDENT_DATE             datetime64[ns]
# INCIDENT_REPORTED_DATE    datetime64[ns]
# CATEGORY                          object
# STAT                               int64
# STAT_DESC                         object
# ADDRESS                           object
# STREET                            object
# CITY                              object
# ZIP                              float64
# INCIDENT_ID                       object
# REPORTING_DISTRICT                 int64
# SEQ                                int64
# GANG_RELATED                      object
# UNIT_ID                           object
# UNIT_NAME                         object
# LONGITUDE                        float64
# LATITUDE                         float64
# PART_CATEGORY                      int64
# dtype: object

# %%
#Filter by Q1/Q2 2019
start_date = '2018-12-31 23:59:59'
end_date = '2019-06-30 23:59:59'

mask = (raw2019['INCIDENT_DATE'] > start_date) & (raw2019['INCIDENT_DATE'] <= end_date)
s2019 = raw2019.loc[mask]
s2019.reset_index(drop=True)
# Out:
#        LURN_SAK       INCIDENT_DATE INCIDENT_REPORTED_DATE  \
# 0      18796349 2019-01-01 00:00:00             2019-01-01
# 1      18796363 2019-01-01 00:00:00             2019-01-01
# 2      18796382 2019-01-01 00:00:00             2019-01-01
# 3      18796434 2019-01-01 00:00:00             2019-01-01
# 4      18799717 2019-01-01 00:00:00             2019-01-04
# ...         ...                 ...                    ...
# 81189  18979069 2019-06-30 23:33:00             2019-06-30
# 81190  18981219 2019-06-30 23:40:00             2019-07-03
# 81191  18979450 2019-06-30 23:49:00             2019-07-01
# 81192  18979091 2019-06-30 23:50:00             2019-07-01
# 81193  18979108 2019-06-30 23:54:00             2019-07-01
#
#                       CATEGORY  STAT  \
# 0      NON-AGGRAVATED ASSAULTS   146
# 1       VEHICLE / BOATING LAWS   250
# 2                LARCENY THEFT    89
# 3       VEHICLE / BOATING LAWS   250
# 4                LARCENY THEFT   387
# ...                        ...   ...
# 81189  DRUNK / ALCOHOL / DRUGS   201
# 81190     FRAUD AND NSF CHECKS   161
# 81191       DISORDERLY CONDUCT   217
# 81192                  ROBBERY    33
# 81193       AGGRAVATED ASSAULT    54
#
#                                                STAT_DESC  \
# 0             ASSAULT, NON-AGGRAVATED: DOMESTIC VIOLENCE
# 1      VEHICLE AND BOATING LAWS: Hit And Run, Misdeme...
# 2      GRAND THEFT: Other (From Boat, Plane, Prvt Res...
# 3      VEHICLE AND BOATING LAWS: Hit And Run, Misdeme...
# 4      THEFT, PETTY: From Bldgs (Church, School, Rest...
# ...                                                  ...
# 81189                                     DRUNK: Alcohol
# 81190     DEFRAUDING: Defrauding Innkeeper (Fel Or Misd)
# 81191            DISORDERLY CONDUCT: Telephone Annoyance
# 81192                   ROBBERY, WEAPON: Service Station
# 81193  ASSAULT, AGGRAVATED: ADW - HANDS, FEET, FIST, ...
#
#                                                ADDRESS  \
# 0                      44300 CAMELIA ST, LANCASTER, CA
# 1                      16000 PIONEER BLVD, NORWALK, CA
# 2         HAZARD AVE AND FAIRMOUNT ST, LOS ANGELES, CA
# 3         14TH ST AND RAILROAD AVE, NEWHALL, CA  91321
# 4      600 N ROBERTSON BLVD, WEST HOLLYWOOD, CA  90069
# ...                                                ...
# 81189         30100 AGOURA RD, AGOURA HILLS, CA  91301
# 81190        9300 ROSECRANS AVE, BELLFLOWER, CA  90706
# 81191        16100 WOODRUFF AVE, BELLFLOWER, CA  90706
# 81192      8300 PEARBLOSSOM HWY, LITTLEROCK, CA  93543
# 81193                 5000 W AVENUE L-3, LANCASTER, CA
#
#                             STREET            CITY      ZIP     INCIDENT_ID  \
# 0                 44300 CAMELIA ST       LANCASTER      NaN  019-00020-1137
# 1               16000 PIONEER BLVD         NORWALK      NaN  919-00016-0455
# 2      HAZARD AVE AND FAIRMOUNT ST     LOS ANGELES      NaN  919-00019-0272
# 3         14TH ST AND RAILROAD AVE         NEWHALL  91321.0  919-00021-0625
# 4             600 N ROBERTSON BLVD  WEST HOLLYWOOD  90069.0  919-00103-0972
# ...                            ...             ...      ...             ...
# 81189              30100 AGOURA RD    AGOURA HILLS  91301.0  919-03620-2224
# 81190           9300 ROSECRANS AVE      BELLFLOWER  90706.0  919-14369-1332
# 81191           16100 WOODRUFF AVE      BELLFLOWER  90706.0  919-14201-1333
# 81192         8300 PEARBLOSSOM HWY      LITTLEROCK  93543.0  919-09275-2660
# 81193            5000 W AVENUE L-3       LANCASTER      NaN  019-13794-1182
#
#        REPORTING_DISTRICT    SEQ GANG_RELATED    UNIT_ID  \
# 0                    1137     20           NO  CA0190024
# 1                     455     16           NO  CA0190004
# 2                     272     19           NO  CA0190002
# 3                     625     21           NO  CA0190006
# 4                     972    103           NO  CA0190009
# ...                   ...    ...          ...        ...
# 81189                2224   3620           NO  CA0190022
# 81190                1332  14369           NO  CA0190013
# 81191                1333  14201           NO  CA0190013
# 81192                2660   9275           NO  CA01900W9
# 81193                1182  13794           NO  CA0190024
#
#                   UNIT_NAME  LONGITUDE  LATITUDE  PART_CATEGORY
# 0                 LANCASTER   -118.080    34.688              2
# 1                   NORWALK   -118.083    33.885              2
# 2          EAST LOS ANGELES   -118.179    34.046              1
# 3      SANTA CLARITA VALLEY   -118.532    34.385              2
# 4            WEST HOLLYWOOD   -118.385    34.083              1
# ...                     ...        ...       ...            ...
# 81189     MALIBU/LOST HILLS   -118.779    34.144              2
# 81190              LAKEWOOD   -118.135    33.904              2
# 81191              LAKEWOOD   -118.116    33.888              2
# 81192              PALMDALE   -117.980    34.519              1
# 81193             LANCASTER   -118.219    34.657              1
#
# [81194 rows x 19 columns]

# %%
#Filter columns
f2019 = s2019[["INCIDENT_DATE", "CATEGORY", "STAT", "STAT_DESC", "ADDRESS", "STREET", "CITY", "ZIP", "INCIDENT_ID", "REPORTING_DISTRICT", "GANG_RELATED", "UNIT_ID", "UNIT_NAME", "LONGITUDE", "LATITUDE", "PART_CATEGORY"]]
f2019.reset_index(drop=True)
# Out:
#             INCIDENT_DATE                 CATEGORY  STAT  \
# 0     2019-01-01 00:00:00  NON-AGGRAVATED ASSAULTS   146
# 1     2019-01-01 00:00:00   VEHICLE / BOATING LAWS   250
# 2     2019-01-01 00:00:00            LARCENY THEFT    89
# 3     2019-01-01 00:00:00   VEHICLE / BOATING LAWS   250
# 4     2019-01-01 00:00:00            LARCENY THEFT   387
# ...                   ...                      ...   ...
# 81189 2019-06-30 23:33:00  DRUNK / ALCOHOL / DRUGS   201
# 81190 2019-06-30 23:40:00     FRAUD AND NSF CHECKS   161
# 81191 2019-06-30 23:49:00       DISORDERLY CONDUCT   217
# 81192 2019-06-30 23:50:00                  ROBBERY    33
# 81193 2019-06-30 23:54:00       AGGRAVATED ASSAULT    54
#
#                                                STAT_DESC  \
# 0             ASSAULT, NON-AGGRAVATED: DOMESTIC VIOLENCE
# 1      VEHICLE AND BOATING LAWS: Hit And Run, Misdeme...
# 2      GRAND THEFT: Other (From Boat, Plane, Prvt Res...
# 3      VEHICLE AND BOATING LAWS: Hit And Run, Misdeme...
# 4      THEFT, PETTY: From Bldgs (Church, School, Rest...
# ...                                                  ...
# 81189                                     DRUNK: Alcohol
# 81190     DEFRAUDING: Defrauding Innkeeper (Fel Or Misd)
# 81191            DISORDERLY CONDUCT: Telephone Annoyance
# 81192                   ROBBERY, WEAPON: Service Station
# 81193  ASSAULT, AGGRAVATED: ADW - HANDS, FEET, FIST, ...
#
#                                                ADDRESS  \
# 0                      44300 CAMELIA ST, LANCASTER, CA
# 1                      16000 PIONEER BLVD, NORWALK, CA
# 2         HAZARD AVE AND FAIRMOUNT ST, LOS ANGELES, CA
# 3         14TH ST AND RAILROAD AVE, NEWHALL, CA  91321
# 4      600 N ROBERTSON BLVD, WEST HOLLYWOOD, CA  90069
# ...                                                ...
# 81189         30100 AGOURA RD, AGOURA HILLS, CA  91301
# 81190        9300 ROSECRANS AVE, BELLFLOWER, CA  90706
# 81191        16100 WOODRUFF AVE, BELLFLOWER, CA  90706
# 81192      8300 PEARBLOSSOM HWY, LITTLEROCK, CA  93543
# 81193                 5000 W AVENUE L-3, LANCASTER, CA
#
#                             STREET            CITY      ZIP     INCIDENT_ID  \
# 0                 44300 CAMELIA ST       LANCASTER      NaN  019-00020-1137
# 1               16000 PIONEER BLVD         NORWALK      NaN  919-00016-0455
# 2      HAZARD AVE AND FAIRMOUNT ST     LOS ANGELES      NaN  919-00019-0272
# 3         14TH ST AND RAILROAD AVE         NEWHALL  91321.0  919-00021-0625
# 4             600 N ROBERTSON BLVD  WEST HOLLYWOOD  90069.0  919-00103-0972
# ...                            ...             ...      ...             ...
# 81189              30100 AGOURA RD    AGOURA HILLS  91301.0  919-03620-2224
# 81190           9300 ROSECRANS AVE      BELLFLOWER  90706.0  919-14369-1332
# 81191           16100 WOODRUFF AVE      BELLFLOWER  90706.0  919-14201-1333
# 81192         8300 PEARBLOSSOM HWY      LITTLEROCK  93543.0  919-09275-2660
# 81193            5000 W AVENUE L-3       LANCASTER      NaN  019-13794-1182
#
#        REPORTING_DISTRICT GANG_RELATED    UNIT_ID             UNIT_NAME  \
# 0                    1137           NO  CA0190024             LANCASTER
# 1                     455           NO  CA0190004               NORWALK
# 2                     272           NO  CA0190002      EAST LOS ANGELES
# 3                     625           NO  CA0190006  SANTA CLARITA VALLEY
# 4                     972           NO  CA0190009        WEST HOLLYWOOD
# ...                   ...          ...        ...                   ...
# 81189                2224           NO  CA0190022     MALIBU/LOST HILLS
# 81190                1332           NO  CA0190013              LAKEWOOD
# 81191                1333           NO  CA0190013              LAKEWOOD
# 81192                2660           NO  CA01900W9              PALMDALE
# 81193                1182           NO  CA0190024             LANCASTER
#
#        LONGITUDE  LATITUDE  PART_CATEGORY
# 0       -118.080    34.688              2
# 1       -118.083    33.885              2
# 2       -118.179    34.046              1
# 3       -118.532    34.385              2
# 4       -118.385    34.083              1
# ...          ...       ...            ...
# 81189   -118.779    34.144              2
# 81190   -118.135    33.904              2
# 81191   -118.116    33.888              2
# 81192   -117.980    34.519              1
# 81193   -118.219    34.657              1
#
# [81194 rows x 16 columns]

# %%
dfTest = f2019.head()
zip = pd.read_csv('C:/Users/hanna/Documents/CSV/CA_Zip_Codes.csv', sep = ',')
testmask = (dfTest['ZIP'].isnull())
dfTest.loc[testmask]
#dfTest.loc[testmask, 'ZIP'] = zip['postal code']
#dfTest.loc[testmask and (dfTest['LATITUDE'] == zip['latitude']) and (dfTest['LONGITUDE'] == zip['longitude']), 'ZIP'] = zip['postal code']

def findZ(lat, log):
    if lat == zip['latitude'] and log == zip['longitude']:
        z = zip['postal code']
    else:
        return 0

# %% [markdown]
# ### Data Checks

# %%
#Data types
f2019.dtypes
# Out:
# INCIDENT_DATE         datetime64[ns]
# CATEGORY                      object
# STAT                           int64
# STAT_DESC                     object
# ADDRESS                       object
# STREET                        object
# CITY                          object
# ZIP                          float64
# INCIDENT_ID                   object
# REPORTING_DISTRICT             int64
# GANG_RELATED                  object
# UNIT_ID                       object
# UNIT_NAME                     object
# LONGITUDE                    float64
# LATITUDE                     float64
# PART_CATEGORY                  int64
# dtype: object

# %%
#Length (columns)
len(f2019.columns)
# Out:
# 16

# %%
#Length (rows)
len(f2019)
# Out:
# 81194

# %%
#Rows and columns
f2019.shape
# Out:
# (81194, 16)

# %%
#Duplicates
f2019.duplicated()
# Out:
# 153216    False
# 44889     False
# 153043    False
# 143678    False
# 10582     False
#           ...
# 57089     False
# 58322     False
# 85793     False
# 36816     False
# 100263    False
# Length: 81194, dtype: bool

# %%
#Duplicates (Count)
f2019.duplicated().sum()
# Out:
# 0

# %%
#Count null values for each column
f2019.isnull().sum()
# Out:
# INCIDENT_DATE             0
# CATEGORY                  0
# STAT                      0
# STAT_DESC                 0
# ADDRESS                 765
# STREET                 1113
# CITY                    765
# ZIP                   37193
# INCIDENT_ID               0
# REPORTING_DISTRICT        0
# GANG_RELATED              0
# UNIT_ID                   0
# UNIT_NAME                 0
# LONGITUDE              4136
# LATITUDE               4136
# PART_CATEGORY             0
# dtype: int64

# %%
#Unique values
f2019.nunique()
# Out:
# INCIDENT_DATE         54584
# CATEGORY                 30
# STAT                    227
# STAT_DESC               227
# ADDRESS               46810
# STREET                37995
# CITY                    239
# ZIP                     292
# INCIDENT_ID           81193
# REPORTING_DISTRICT     1090
# GANG_RELATED              2
# UNIT_ID                  52
# UNIT_NAME                53
# LONGITUDE              1132
# LATITUDE                998
# PART_CATEGORY             2
# dtype: int64

# %% [markdown]
# ### Export

# %%
#Export to csv
f2019.to_csv('C:/Users/hanna/Documents/CSV/CRIMESDATA/LA_2019.csv')

# %% [markdown]
# ### 2019 July - December

# %%
#Filter by Q3/Q4 2019
start_date = '2019-06-30 23:59:59'
end_date = '2019-12-31 23:59:59'

mask = (raw2019['INCIDENT_DATE'] > start_date) & (raw2019['INCIDENT_DATE'] <= end_date)
e2019 = raw2019.loc[mask]
e2019.reset_index(drop=True)
e2019.shape
# Out:
# (79146, 19)

# %% [markdown]
# ### 2019 - Incidents that did not occur in 2019 but were reported in 2019

# %%
mask = (raw2019['INCIDENT_DATE'].dt.year != 2019)
nr2019 = raw2019.loc[mask]
nr2019.reset_index(drop=True)
nr2019.shape
# Out:
# (3098, 19)
