# %%
import pandas as pd
import numpy as np
from datetime import datetime, date

# %%
raw2019 = pd.read_csv('C:/Users/hanna/Documents/CSV/CRIMESDATA/2019-PART_I_AND_II_CRIMES.csv', sep = ',')
raw2019.head()
#raw2019.dtypes
# Out:
#    LURN_SAK           INCIDENT_DATE INCIDENT_REPORTED_DATE  \
# 0  18928343  05/09/2019 04:05:00 AM             05/09/2019
# 1  18868348  03/17/2019 10:05:00 AM             03/17/2019
# 2  18830941  02/05/2019 07:57:00 PM             02/05/2019
# 3  18959726  06/09/2019 11:15:00 PM             06/10/2019
# 4  18974981  06/25/2019 07:00:00 PM             06/26/2019
#
#                  CATEGORY  STAT  \
# 0  VEHICLE / BOATING LAWS   255
# 1  VEHICLE / BOATING LAWS   255
# 2             WEAPON LAWS   151
# 3        GRAND THEFT AUTO    91
# 4        GRAND THEFT AUTO    91
#
#                                            STAT_DESC  \
# 0              VEHICLE AND BOATING LAWS: Misdemeanor
# 1              VEHICLE AND BOATING LAWS: Misdemeanor
# 2                                WEAPON LAWS: Felony
# 3  GRAND THEFT VEHICLE (GTA): Automobile/Passenge...
# 4  GRAND THEFT VEHICLE (GTA): Automobile/Passenge...
#
#                                              ADDRESS  \
# 0                CALORA ST AND GRAND AVE, COVINA, CA
# 1   TEMPLE AVE AND VINELAND AVE, INDUSTRY, CA  91744
# 2  CRESTWOOD ST AND WESTERN AVE, RANCHO PALOS VER...
# 3                      11200 BEZCHER ST, NORWALK, CA
# 4                    21800 VALLEY BLVD, INDUSTRY, CA
#
#                          STREET                 CITY      ZIP     INCIDENT_ID  \
# 0       CALORA ST AND GRAND AVE               COVINA      NaN  919-02408-0870
# 1   TEMPLE AVE AND VINELAND AVE             INDUSTRY  91744.0  919-03554-1412
# 2  CRESTWOOD ST AND WESTERN AVE  RANCHO PALOS VERDES  90275.0  919-00421-1746
# 3              11200 BEZCHER ST              NORWALK      NaN  919-08383-0451
# 4             21800 VALLEY BLVD             INDUSTRY      NaN  919-08479-1419
#
#    REPORTING_DISTRICT   SEQ GANG_RELATED    UNIT_ID  UNIT_NAME  LONGITUDE  \
# 0                 870  2408           NO  CA0190008  SAN DIMAS   -117.872
# 1                1412  3554           NO  CA0190014   INDUSTRY   -117.986
# 2                1746   421           NO  CA0190017     LOMITA   -118.309
# 3                 451  8383           NO  CA0190004    NORWALK   -118.093
# 4                1419  8479           NO  CA0190014   INDUSTRY   -117.832
#
#    LATITUDE  PART_CATEGORY
# 0    34.104              2
# 1    34.053              2
# 2    33.750              2
# 3    33.910              1
# 4    34.028              1

# %%
raw2019['INCIDENT_DATE'] = pd.to_datetime(raw2019['INCIDENT_DATE'], format = '%m/%d/%Y %I:%M:%S %p')
raw2019['INCIDENT_REPORTED_DATE'] = pd.to_datetime(raw2019['INCIDENT_REPORTED_DATE'], format = '%m/%d/%Y')
raw2019 = raw2019.sort_values(by=['INCIDENT_DATE', 'INCIDENT_REPORTED_DATE', 'INCIDENT_ID'], ascending=[True, True, True])
#raw2019.dtypes
#raw2019.tail()
raw2019.head()
# Out:
#         LURN_SAK       INCIDENT_DATE INCIDENT_REPORTED_DATE  \
# 155730  18820256 1976-01-01 12:00:00             2019-01-25
# 11458   19040544 1976-01-01 12:05:45             2019-09-03
# 95726   18860114 1979-01-01 00:00:00             2019-03-08
# 87066   18931381 1979-07-02 11:59:30             2019-05-12
# 70079   18899023 1979-07-02 12:00:00             2019-04-18
#
#                      CATEGORY  STAT  \
# 155730  SEX OFFENSES FELONIES   120
# 11458   SEX OFFENSES FELONIES   120
# 95726           FORCIBLE RAPE    23
# 87066   SEX OFFENSES FELONIES   120
# 70079           FORCIBLE RAPE    27
#
#                                                 STAT_DESC  \
# 155730  SEX FELONIES: Sex Crimes Against Children (Und...
# 11458   SEX FELONIES: Sex Crimes Against Children (Und...
# 95726                      RAPE BY FORCE, FEMALE UNDER 18
# 87066   SEX FELONIES: Sex Crimes Against Children (Und...
# 70079                        RAPE BY FORCE, MALE UNDER 18
#
#                                       ADDRESS              STREET      CITY  \
# 155730  19800 LORENCITA DR, COVINA, CA  91724  19800 LORENCITA DR    COVINA
# 11458                       UNK, LAKEWOOD, CA                 UNK  LAKEWOOD
# 95726   26300 ESHELMAN AVE, LOMITA, CA  90717  26300 ESHELMAN AVE    LOMITA
# 87066   28800 SELFRIDGE DR, MALIBU, CA  90265  28800 SELFRIDGE DR    MALIBU
# 70079           5200 ELIZABETH ST, CUDAHY, CA   5200 ELIZABETH ST    CUDAHY
#
#             ZIP     INCIDENT_ID  REPORTING_DISTRICT    SEQ GANG_RELATED  \
# 155730  91724.0  019-00651-2941                2941    651           NO
# 11458       NaN  019-19248-1322                1322  19248           NO
# 95726   90717.0  019-00806-1713                1713    806           NO
# 87066   90265.0  019-02523-1013                1013   2523           NO
# 70079       NaN  019-05536-0262                 262   5536           NO
#
#           UNIT_ID          UNIT_NAME  LONGITUDE  LATITUDE  PART_CATEGORY
# 155730  CA0190020             WALNUT   -117.865    34.064              2
# 11458   CA0190013           LAKEWOOD        NaN       NaN              2
# 95726   CA0190017             LOMITA   -118.314    33.783              1
# 87066   CA0190022  MALIBU/LOST HILLS   -118.799    34.019              2
# 70079   CA0190002   EAST LOS ANGELES   -118.173    33.962              1

# %%
start_date = '2018-12-31 23:59:59'
end_date = '2019-06-30 23:59:59'
#sdate = raw2019["INCIDENT_DATE"] >= start_date
#edate = raw2019["INCIDENT_DATE"] <= end_date
#between = sdate & edate
#s2019 = raw2019.loc[between]
#s2019 = s2019.sort_values(by='INCIDENT_DATE', ascending=True)

#s2019 = raw2019.loc[raw2019['INCIDENT_DATE'].between(start_date, end_date)]

mask = (raw2019['INCIDENT_DATE'] >= start_date) & (raw2019['INCIDENT_DATE'] <= end_date)
s2019 = raw2019.loc[mask]
s2019
# Out:
#         LURN_SAK       INCIDENT_DATE INCIDENT_REPORTED_DATE  \
# 153216  18796349 2019-01-01 00:00:00             2019-01-01
# 44889   18796363 2019-01-01 00:00:00             2019-01-01
# 153043  18796382 2019-01-01 00:00:00             2019-01-01
# 143678  18796434 2019-01-01 00:00:00             2019-01-01
# 10582   18799717 2019-01-01 00:00:00             2019-01-04
# ...          ...                 ...                    ...
# 57089   18979069 2019-06-30 23:33:00             2019-06-30
# 58322   18981219 2019-06-30 23:40:00             2019-07-03
# 85793   18979450 2019-06-30 23:49:00             2019-07-01
# 36816   18979091 2019-06-30 23:50:00             2019-07-01
# 100263  18979108 2019-06-30 23:54:00             2019-07-01
#
#                        CATEGORY  STAT  \
# 153216  NON-AGGRAVATED ASSAULTS   146
# 44889    VEHICLE / BOATING LAWS   250
# 153043            LARCENY THEFT    89
# 143678   VEHICLE / BOATING LAWS   250
# 10582             LARCENY THEFT   387
# ...                         ...   ...
# 57089   DRUNK / ALCOHOL / DRUGS   201
# 58322      FRAUD AND NSF CHECKS   161
# 85793        DISORDERLY CONDUCT   217
# 36816                   ROBBERY    33
# 100263       AGGRAVATED ASSAULT    54
#
#                                                 STAT_DESC  \
# 153216         ASSAULT, NON-AGGRAVATED: DOMESTIC VIOLENCE
# 44889   VEHICLE AND BOATING LAWS: Hit And Run, Misdeme...
# 153043  GRAND THEFT: Other (From Boat, Plane, Prvt Res...
# 143678  VEHICLE AND BOATING LAWS: Hit And Run, Misdeme...
# 10582   THEFT, PETTY: From Bldgs (Church, School, Rest...
# ...                                                   ...
# 57089                                      DRUNK: Alcohol
# 58322      DEFRAUDING: Defrauding Innkeeper (Fel Or Misd)
# 85793             DISORDERLY CONDUCT: Telephone Annoyance
# 36816                    ROBBERY, WEAPON: Service Station
# 100263  ASSAULT, AGGRAVATED: ADW - HANDS, FEET, FIST, ...
#
#                                                 ADDRESS  \
# 153216                  44300 CAMELIA ST, LANCASTER, CA
# 44889                   16000 PIONEER BLVD, NORWALK, CA
# 153043     HAZARD AVE AND FAIRMOUNT ST, LOS ANGELES, CA
# 143678     14TH ST AND RAILROAD AVE, NEWHALL, CA  91321
# 10582   600 N ROBERTSON BLVD, WEST HOLLYWOOD, CA  90069
# ...                                                 ...
# 57089          30100 AGOURA RD, AGOURA HILLS, CA  91301
# 58322         9300 ROSECRANS AVE, BELLFLOWER, CA  90706
# 85793         16100 WOODRUFF AVE, BELLFLOWER, CA  90706
# 36816       8300 PEARBLOSSOM HWY, LITTLEROCK, CA  93543
# 100263                 5000 W AVENUE L-3, LANCASTER, CA
#
#                              STREET            CITY      ZIP     INCIDENT_ID  \
# 153216             44300 CAMELIA ST       LANCASTER      NaN  019-00020-1137
# 44889            16000 PIONEER BLVD         NORWALK      NaN  919-00016-0455
# 153043  HAZARD AVE AND FAIRMOUNT ST     LOS ANGELES      NaN  919-00019-0272
# 143678     14TH ST AND RAILROAD AVE         NEWHALL  91321.0  919-00021-0625
# 10582          600 N ROBERTSON BLVD  WEST HOLLYWOOD  90069.0  919-00103-0972
# ...                             ...             ...      ...             ...
# 57089               30100 AGOURA RD    AGOURA HILLS  91301.0  919-03620-2224
# 58322            9300 ROSECRANS AVE      BELLFLOWER  90706.0  919-14369-1332
# 85793            16100 WOODRUFF AVE      BELLFLOWER  90706.0  919-14201-1333
# 36816          8300 PEARBLOSSOM HWY      LITTLEROCK  93543.0  919-09275-2660
# 100263            5000 W AVENUE L-3       LANCASTER      NaN  019-13794-1182
#
#         REPORTING_DISTRICT    SEQ GANG_RELATED    UNIT_ID  \
# 153216                1137     20           NO  CA0190024
# 44889                  455     16           NO  CA0190004
# 153043                 272     19           NO  CA0190002
# 143678                 625     21           NO  CA0190006
# 10582                  972    103           NO  CA0190009
# ...                    ...    ...          ...        ...
# 57089                 2224   3620           NO  CA0190022
# 58322                 1332  14369           NO  CA0190013
# 85793                 1333  14201           NO  CA0190013
# 36816                 2660   9275           NO  CA01900W9
# 100263                1182  13794           NO  CA0190024
#
#                    UNIT_NAME  LONGITUDE  LATITUDE  PART_CATEGORY
# 153216             LANCASTER   -118.080    34.688              2
# 44889                NORWALK   -118.083    33.885              2
# 153043      EAST LOS ANGELES   -118.179    34.046              1
# 143678  SANTA CLARITA VALLEY   -118.532    34.385              2
# 10582         WEST HOLLYWOOD   -118.385    34.083              1
# ...                      ...        ...       ...            ...
# 57089      MALIBU/LOST HILLS   -118.779    34.144              2
# 58322               LAKEWOOD   -118.135    33.904              2
# 85793               LAKEWOOD   -118.116    33.888              2
# 36816               PALMDALE   -117.980    34.519              1
# 100263             LANCASTER   -118.219    34.657              1
#
# [81194 rows x 19 columns]
