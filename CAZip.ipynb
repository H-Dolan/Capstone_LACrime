# %%
import pandas as pd

# %%
zip = pd.read_csv('C:/Users/hanna/Documents/CSV/zip_to_lat_lon_North America.csv', sep = ',')
mask = (zip['state'] == 'California')
caZ = zip.loc[mask]
caZ["postalcode"] = caZ["postalcode"].astype(dtype = 'float64')
caZ.reset_index(drop=True)
caZ
# Out:
# C:\Users\hanna\AppData\Local\Temp\ipykernel_8328\2799217197.py:1: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   zip = pd.read_csv('C:/Users/hanna/Documents/CSV/zip_to_lat_lon_North America.csv', sep = ',')
# C:\Users\hanna\AppData\Local\Temp\ipykernel_8328\2799217197.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caZ["postalcode"] = caZ["postalcode"].astype(dtype = 'float64')
#        countrycode  postalcode              place       state statecode  \
# 150722          US     94501.0            Alameda  California        CA
# 150723          US     94502.0            Alameda  California        CA
# 150724          US     94536.0            Fremont  California        CA
# 150725          US     94537.0            Fremont  California        CA
# 150726          US     94538.0            Fremont  California        CA
# ...            ...         ...                ...         ...       ...
# 153308          US     95935.0            Dobbins  California        CA
# 153309          US     95961.0         Olivehurst  California        CA
# 153310          US     95962.0       Oregon House  California        CA
# 153311          US     95972.0           Rackerby  California        CA
# 153312          US     95981.0  Strawberry Valley  California        CA
#
#        province_or_county  province_or_countycode community  communitycode  \
# 150722            Alameda                     1.0       NaN            NaN
# 150723            Alameda                     1.0       NaN            NaN
# 150724            Alameda                     1.0       NaN            NaN
# 150725            Alameda                     1.0       NaN            NaN
# 150726            Alameda                     1.0       NaN            NaN
# ...                   ...                     ...       ...            ...
# 153308               Yuba                   115.0       NaN            NaN
# 153309               Yuba                   115.0       NaN            NaN
# 153310               Yuba                   115.0       NaN            NaN
# 153311               Yuba                   115.0       NaN            NaN
# 153312               Yuba                   115.0       NaN            NaN
#
#         latitude  longitude  accuracy        Country      Continent
# 150722   37.7706  -122.2648       4.0  United States  North America
# 150723   37.7351  -122.2431       4.0  United States  North America
# 150724   37.5605  -121.9999       4.0  United States  North America
# 150725   37.6802  -121.9215       4.0  United States  North America
# 150726   37.5308  -121.9712       4.0  United States  North America
# ...          ...        ...       ...            ...            ...
# 153308   39.3662  -121.2256       4.0  United States  North America
# 153309   39.0861  -121.5497       4.0  United States  North America
# 153310   39.3459  -121.2663       4.0  United States  North America
# 153311   39.4256  -121.3252       4.0  United States  North America
# 153312   39.6870  -121.0450       4.0  United States  North America
#
# [2591 rows x 14 columns]

# %%
#Export to csv
caZ.to_csv('C:/Users/hanna/Documents/CSV/CA_Zip_Codes.csv')
