# %%
import pandas as pd

# %%
zip = pd.read_csv('C:/Users/hanna/Documents/CSV/zip_to_lat_lon_North America.csv', sep = ',')
mask = (zip['state'] == 'California')
caZ = zip.loc[mask]
caZ["postalcode"] = caZ["postalcode"].astype(dtype = 'Int64')
caZ.reset_index(drop=True)
# Out:
# C:\Users\hanna\AppData\Local\Temp\ipykernel_13656\175960343.py:1: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   zip = pd.read_csv('C:/Users/hanna/Documents/CSV/zip_to_lat_lon_North America.csv', sep = ',')
# C:\Users\hanna\AppData\Local\Temp\ipykernel_13656\175960343.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caZ["postalcode"] = caZ["postalcode"].astype(dtype = 'Int64')
#      countrycode  postalcode              place       state statecode  \
# 0             US       94501            Alameda  California        CA
# 1             US       94502            Alameda  California        CA
# 2             US       94536            Fremont  California        CA
# ...

# %%
caZ = caZ[['postalcode', 'place', 'statecode', 'province_or_county','latitude', 'longitude']]
caZ.reset_index(drop=True)
# Out:
#       postalcode              place statecode province_or_county  latitude  \
# 0          94501            Alameda        CA            Alameda   37.7706
# 1          94502            Alameda        CA            Alameda   37.7351
# 2          94536            Fremont        CA            Alameda   37.5605
# 3          94537            Fremont        CA            Alameda   37.6802
# 4          94538            Fremont        CA            Alameda   37.5308
# ...          ...                ...       ...                ...       ...
# 2586       95935            Dobbins        CA               Yuba   39.3662
# 2587       95961         Olivehurst        CA               Yuba   39.0861
# 2588       95962       Oregon House        CA               Yuba   39.3459
# 2589       95972           Rackerby        CA               Yuba   39.4256
# 2590       95981  Strawberry Valley        CA               Yuba   39.6870
#
#       longitude
# 0     -122.2648
# 1     -122.2431
# ...

# %%
#Export to csv
caZ.to_csv('C:/Users/hanna/Documents/CSV/CA_Zip_Codes.csv')
